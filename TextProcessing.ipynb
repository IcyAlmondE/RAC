# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

service = Service("C:\\Users\\Asus\\OneDrive\\Desktop\\IcyAlmondE\\RAC\\16-25 Oct\\chromedriver-win64\\chromedriver.exe")
driver = webdriver.Chrome(service=service)
# driver = webdriver.Chrome('/Users/sukreesinthupinyo/App/chromedriver')
driver.implicitly_wait(30)
driver.maximize_window()

# %%
driver.get('https://www.twitter.com/POTUS')

# %%
import time
for i in range(5):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(1)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
soup
# Out:
# <html dir="ltr" lang="en" style="overflow: auto scroll; overscroll-behavior-y: none; font-size: 15px;"><head><style>input::placeholder { user-select: none; -webkit-user-select: none; } iframe { color-scheme: auto; }</style><style>@font-face {
#   font-family: TwitterChirp;
#   src: url(https://abs.twimg.com/responsive-web/client-web/Chirp-Light.3a18e64a.woff2) format('woff2'), url(https://abs.twimg.com/responsive-web/client-web/Chirp-Light.7a5673aa.woff) format('woff');
#   font-weight: 300;
#   font-style: 'normal';
#   font-display: 'swap';
# }
# @font-face {
#   font-family: TwitterChirp;
#   src: url(https://abs.twimg.com/responsive-web/client-web/Chirp-Regular.80fda27a.woff2) format('woff2'), url(https://abs.twimg.com/responsive-web/client-web/Chirp-Regular.60b215ba.woff) format('woff');
#   font-weight: 400;
#   font-style: 'normal';
#   font-display: 'swap';
# }
# @font-face {
#   font-family: TwitterChirp;
# ...

# %%
tweets = soup.find_all('div', {'class':'css-1dbjc4n r-16y2uox r-1wbh5a2 r-1ny4l3l'})

# %%
for tweet in tweets:
    s1=tweet.find('div', {'class':'css-901oao css-cens5h r-18jsvk2 r-37j5jr r-a023e6 r-16dba41 r-rjixqe r-bcqeeo r-bnwqim r-qvutc0'})
    print(s1.text)
    print('*************************************')
# Out:
# It was great to meet with you, @bts_bighit. Thanks for all you’re doing to raise awareness around the rise in anti-Asian hate crimes and discrimination.
#
# I look forward to sharing more of our conversation soon.
# *************************************
# It was great to meet with you this week at the White House, @bts_bighit. The rise in anti-Asian hate crimes requires all of us to stand up, speak out, and give hate no safe harbor. Thanks for all you’re doing. It matters.
# *************************************
# As I’ve said before, no one should be in jail just for using or possessing marijuana.
#
# Today, I’m taking steps to end our failed approach. Allow me to lay them out.
# *************************************
# We're back in the Paris Climate Agreement.
# *************************************
# Grateful for the short commute on days like these.
# *************************************
# I just want to make a few things clear:
#
# The Holocaust happened.
#
# ...

# %%
driver.get('https://www.thairath.co.th/home')

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
for i in range(12):
    class_name = '__item_sectionnew_{} css-t8rc5b e11fmmx10'.format(i)
    # print(class_name)
    news_section = soup.find('div', {'class':class_name})
    att=news_section.find('a')
    print(att['href'])
    print(att['title'])
# Out:
# /news/politic/2734908
# “สุทิน” พร้อมแจง กมธ.สภาฯ เลื่อนซื้อเรือดำน้ำจีน ยัน คิดและหารือรอบคอบแล้ว
# /agriculture/agricultural-product-prices/2734903
# ราคาหมูหน้าฟาร์มปรับขึ้นแล้ว กก.ละ 4 บาท คาดมาจากการปราบหมูเถื่อนอย่างจริงจัง
# /agriculture/agricultural-products/2734868
# ผู้กองจราจรเมืองสุโขทัย ทำฟาร์มปลาไหลเพาะที่บ้าน รายได้ปัง ตลาดรับซื้อไม่อั้น
# /news/politic/2734902
# นายกฯ วางพวงมาลาวันปิยมหาราช 2566 เผย ยังไม่ได้รับรายงาน “เสี่ยแป้ง นาโหนด”
# /agriculture/agricultural-products/2734867
# พบวัวของชาวบ้านใน อ.ห้วยแถลง โคราช ป่วยด้วยโรคลัมปีสกิน ทำตายไปแล้ว 4 ตัว
# /sport/others/2734900
# ทองแรกมาแล้ว "ชัยวัฒน์" ซิ่งวีลแชร์เข้าวิน 100 ม. พ่วงพังสถิติ เอเชียนพาราเกมส์ "หางโจว 2022"
# /agriculture/agricultural-product-prices/2734866
# พาณิชย์พาโรงสีภาคกลางรับซื้อข้าวเหนียวใน 7 จังหวัดเหนือ กระตุ้นราคาในพื้นที่
# /news/politic/2734897
# เช็กชื่อ 515 คนกลับไทยวันนี้ 2 เที่ยวบิน “เศรษฐา” นำประชุมศูนย์ฉุกเฉินบ่าย
# /sport/eurofootball/seriea/2734890
# ...

# %%
from selenium.webdriver.common.by import By


for i in range(1,14):
    if i == 6:
        continue
    button=driver.find_element(By.ID, "activeMenu0"+str(i))
    button.click()
    time.sleep(2)

    for j in range(12):
        class_name = '__item_sectionnew_{} css-t8rc5b e11fmmx10'.format(j)
        # print(class_name)
        news_section = soup.find('div', {'class':class_name})
        att=news_section.find('a')
        print(att['href'])
        print(att['title'])
# Out:
# /news/politic/2734908
# “สุทิน” พร้อมแจง กมธ.สภาฯ เลื่อนซื้อเรือดำน้ำจีน ยัน คิดและหารือรอบคอบแล้ว
# /agriculture/agricultural-product-prices/2734903
# ราคาหมูหน้าฟาร์มปรับขึ้นแล้ว กก.ละ 4 บาท คาดมาจากการปราบหมูเถื่อนอย่างจริงจัง
# /agriculture/agricultural-products/2734868
# ผู้กองจราจรเมืองสุโขทัย ทำฟาร์มปลาไหลเพาะที่บ้าน รายได้ปัง ตลาดรับซื้อไม่อั้น
# /news/politic/2734902
# นายกฯ วางพวงมาลาวันปิยมหาราช 2566 เผย ยังไม่ได้รับรายงาน “เสี่ยแป้ง นาโหนด”
# /agriculture/agricultural-products/2734867
# พบวัวของชาวบ้านใน อ.ห้วยแถลง โคราช ป่วยด้วยโรคลัมปีสกิน ทำตายไปแล้ว 4 ตัว
# /sport/others/2734900
# ทองแรกมาแล้ว "ชัยวัฒน์" ซิ่งวีลแชร์เข้าวิน 100 ม. พ่วงพังสถิติ เอเชียนพาราเกมส์ "หางโจว 2022"
# /agriculture/agricultural-product-prices/2734866
# พาณิชย์พาโรงสีภาคกลางรับซื้อข้าวเหนียวใน 7 จังหวัดเหนือ กระตุ้นราคาในพื้นที่
# /news/politic/2734897
# เช็กชื่อ 515 คนกลับไทยวันนี้ 2 เที่ยวบิน “เศรษฐา” นำประชุมศูนย์ฉุกเฉินบ่าย
# /sport/eurofootball/seriea/2734890
# ...

# %%
button.click()

# %%
soup=BeautifulSoup(driver.page_source, 'html.parser')
tab_content=soup.find('div', {'class':'tab-content'})

# %%
for d in tab_content.find_all('div', {'class':'tab-pane'}):
    atts = d.find_all('a')
    for att in atts:
        print(att.text)
# Out:
# ก.เกษตรฯ เดินหน้า “ชัยนาทโมเดล” หนุนชาวนามีอาชีพเสริม เพิ่มรายได้พ้นความยากจน
# นโยบายการเกษตร
#
# “สุทิน” พร้อมแจง กมธ.สภาฯ เลื่อนซื้อเรือดำน้ำจีน ยัน คิดและหารือรอบคอบแล้ว
# การเมือง
#
# ราคาหมูหน้าฟาร์มปรับขึ้นแล้ว กก.ละ 4 บาท คาดมาจากการปราบหมูเถื่อนอย่างจริงจัง
# ราคาผลผลิตการเกษตร
#
# ผู้กองจราจรเมืองสุโขทัย ทำฟาร์มปลาไหลเพาะที่บ้าน รายได้ปัง ตลาดรับซื้อไม่อั้น
# สินค้าเกษตร
#
# นายกฯ วางพวงมาลาวันปิยมหาราช 2566 เผย ยังไม่ได้รับรายงาน “เสี่ยแป้ง นาโหนด”
# การเมือง
#
# พบวัวของชาวบ้านใน อ.ห้วยแถลง โคราช ป่วยด้วยโรคลัมปีสกิน ทำตายไปแล้ว 4 ตัว
# สินค้าเกษตร
#
# ทองแรกมาแล้ว "ชัยวัฒน์" ซิ่งวีลแชร์เข้าวิน 100 ม. พ่วงพังสถิติ เอเชียนพาราเกมส์ "หางโจว 2022"
# กีฬาอื่นๆ
#
# พาณิชย์พาโรงสีภาคกลางรับซื้อข้าวเหนียวใน 7 จังหวัดเหนือ กระตุ้นราคาในพื้นที่
# ราคาผลผลิตการเกษตร
#
# เช็กชื่อ 515 คนกลับไทยวันนี้ 2 เที่ยวบิน “เศรษฐา” นำประชุมศูนย์ฉุกเฉินบ่าย
# การเมือง
#
# อยู่ดีไม่ว่าดี "มูรินโญ" ทำท่าเย้ยหยันใส่กุนซือ "มอนซา" กรรมการเห็นเลยแจกใบแดง (คลิป)
# กัลโช่ อิตาลี
#
# ...
